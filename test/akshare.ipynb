# %%
import akshare as ak
# Out:
# d:\Documents\miniconda3\envs\crawlerEnv\lib\site-packages\akshare\__init__.py:2709: UserWarning: 为了支持更多特性，请将 Pandas 升级到 2.1.0 及以上版本！
#   warnings.warn(

# %%
stock_zh_a_hist_df = ak.stock_zh_a_hist(
    symbol="600734", 
    period="daily", 
    start_date="20050501", 
    end_date="20050520", 
    adjust="hfq"
)

# %%
stock_zh_a_hist_df
# Out:
#            日期    开盘    收盘    最高    最低    成交量        成交额       振幅     涨跌幅  \
# 0  2005-05-09 -0.13 -0.53  0.00 -0.53   7912  1571616.0   407.69 -507.69
# 1  2005-05-10 -0.53 -0.50 -0.36 -0.79   5978  1150869.0   -81.13    5.66
# 2  2005-05-11 -0.50 -0.30 -0.20 -0.69   8415  1651719.0   -98.00   40.00
# 3  2005-05-12 -0.33 -0.20  0.00 -0.43  10721  2175707.0  -143.33   33.33
# 4  2005-05-13 -0.33 -0.13  0.07 -0.40   7661  1569427.0  -235.00   35.00
# 5  2005-05-16 -0.30 -0.10  0.10 -0.40  11218  2324469.0  -384.62   23.08
# 6  2005-05-17 -0.10  0.04  0.13 -0.23  12758  2682900.0  -360.00  140.00
# 7  2005-05-18  0.00  0.20  0.27 -0.13  10709  2261494.0  1000.00  400.00
# 8  2005-05-19  0.10  0.07  0.17 -0.06   7503  1589463.0   115.00  -65.00
# 9  2005-05-20  0.07  0.00  0.13 -0.03   6404  1355000.0   228.57 -100.00
#
#     涨跌额   换手率
# 0 -0.66  0.60
# 1  0.03  0.45
# 2  0.20  0.63
# 3  0.10  0.81
# 4  0.07  0.58
# 5  0.03  0.85
# 6  0.14  0.96
# 7  0.16  0.81
# 8 -0.13  0.57
# ...

# %%
ak.stock_zh_a_spot_em()
# Out:
#         序号      代码    名称    最新价    涨跌幅    涨跌额       成交量           成交额     振幅  \
# 0        1  603341   N龙旗  51.92  99.69  25.92  339291.0  1.802732e+09  38.38
# 1        2  300713   英可瑞  15.23  20.02   2.54  135782.0  2.021405e+08  16.78
# 2        3  301489  思泉新材  70.08  20.00  11.68   30460.0  2.054043e+08  13.84
# 3        4  300710  万隆光电  18.60  20.00   3.10   38507.0  6.939423e+07  20.00
# 4        5  300870   欧陆通  48.26  19.99   8.04  125038.0  5.584934e+08  22.00
# ...    ...     ...   ...    ...    ...    ...       ...           ...    ...
# 5590  5591  603825  华扬联众  12.56  -9.96  -1.39  516788.0  6.582392e+08   6.59
# 5591  5592  002713  东易日盛   6.50  -9.97  -0.72  670502.0  4.483961e+08   8.17
# 5592  5593  600302  标准股份   5.14  -9.98  -0.57  105844.0  5.440382e+07   0.00
# 5593  5594  830974  凯大催化   8.40 -11.11  -1.05  191720.0  1.696319e+08  14.29
# 5594  5595  301591   C肯特  60.48 -13.97  -9.82  113020.0  7.252255e+08  14.17
#
# ...

# %%
ak.stock_zh_a_hist_min_em(symbol="301591", start_date="2024-01-01 00:00:00", end_date="2024-02-06 00:00:00", period='60', adjust='')
# Out:
# Empty DataFrame
# Columns: [时间, 开盘, 收盘, 最高, 最低, 涨跌幅, 涨跌额, 成交量, 成交额, 振幅, 换手率]
# Index: []

# %%
ak.stock_intraday_em(symbol="000001")
# Out:
#             时间    成交价     手数 买卖盘性质
# 0     09:15:00  10.60    346   中性盘
# 1     09:15:09  10.64   3435   中性盘
# 2     09:15:18  10.64   3435   中性盘
# 3     09:15:27  10.64   3581   中性盘
# 4     09:15:36  10.64   3681   中性盘
# ...        ...    ...    ...   ...
# 4668  14:56:51  10.49    342    买盘
# 4669  14:56:54  10.48    363    卖盘
# 4670  14:56:57  10.49    650    买盘
# 4671  14:57:00  10.49    155    卖盘
# 4672  15:00:00  10.49  23805    卖盘
#
# [4673 rows x 4 columns]
